# %%
printf("hello worl");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 printf("hello worl");
#
# NameError: name 'printf' is not defined

# %%
print("hello world");
# Out:
# hello world
